# %% [markdown]
# # Computer Vision Project
# Noah Hicks (nhicks)
#
# I implement [AlexNet](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks)-like deep, convolutional neural network (CNN) with PyTorch. I use the CNN to classify flowers into the 102 categories.
#
# The project consists of the following parts:
#
# - Load and prepare data.
# - Load a pretrained Alexnet in PyTorch.
# - Set up transfer learning for flower classification problem
# - Train the model
# - Model performance monitoring and analysis with learning curve
# - Questions regarding the design choices
#
# This is made for my Intro to AI class at Carnegie Mellon University. Some code was provided, some was generated by GPT-5, and some was written by myself. All code is approved by myself.

# %% [markdown]
# #### 1.1. Load the dataset which are in three folders, namely train, validation, and test

# %%
import matplotlib.pyplot as plt
from collections import OrderedDict

from copy import deepcopy
import torch
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# download the data and unzip it. You should have three sets of data
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %% [markdown]
# #### 1.2. Preview some images
# Use PIL library to preview images

# %%
from PIL import Image  #show one example of image

Image.open("flowers/train/1/image_06734.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=523x500>

# %% [markdown]
# #### 1.3. Data transformation and processing

# %%
# Process with some data transformation, do not change
data_transforms = {
    'training': transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(30),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224,
                                                          0.225])]),

    'validation': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(
                                          [0.485, 0.456, 0.406],
                                          [0.229, 0.224, 0.225])]),

    'testing': transforms.Compose([transforms.Resize(256),
                                   transforms.CenterCrop(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                        [0.229, 0.224,
                                                         0.225])])
}
# This specifies how many images to process per training/validation
batch_size = 256

image_datasets = {
    'training': datasets.ImageFolder(train_dir,
                                     transform=data_transforms['training']),
    'testing': datasets.ImageFolder(test_dir,
                                    transform=data_transforms['testing']),
    'validation': datasets.ImageFolder(valid_dir,
                                       transform=data_transforms['validation'])
}

dataloaders = {
    'training': torch.utils.data.DataLoader(image_datasets['training'],
                                            batch_size=batch_size,
                                            shuffle=True),
    'testing': torch.utils.data.DataLoader(image_datasets['testing'],
                                           batch_size=batch_size,
                                           shuffle=False),
    'validation': torch.utils.data.DataLoader(image_datasets['validation'],
                                              batch_size=batch_size,
                                              shuffle=True)
}

# get the length of each dataloaders; wit batch size=256, you should have 26 batches of training samples, each with 256 images 
training_len = ???
test_len = ???
validation_len = ???
class_to_idx = image_datasets['training'].class_to_idx

print('We have ', training_len, 'batches of training images;', 'each with',
      batch_size, 'images')
print('We have ', validation_len, 'batches of validation images;', 'each with',
      batch_size, 'images')

# Let us preview size of each batch
print('Single batch', next(iter(dataloaders['training']))[0].shape)
# Out:
#   Cell In[5], line 50
#     training_len = ???
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### *Question 1: What is the effect of random flip and rotation in image data transformation?*
# - How does it impact the training?
# - Why do not we apply them randomly at the validation or test time?

# %% [markdown]
# ### *Question 2: Explain the meaning of these numbers for a single batch*
# - 256: ???
# - 3: ???
# - 224: ???
# - 224: ???

# %% [markdown]
# #### 1.4. Initialize the pretrained model
#
# We are going to use an Alexnet convolutional neural network as our pretrained model. The architecture of the network is shown in
#
#  https://bouzouitina-hamdi.medium.com/alexnet-imagenet-classification-with-deep-convolutional-neural-networks-d0210289746b

# %%
# Transfer learning with alexnet
model = models.alexnet(pretrained=True)

# %% [markdown]
# ### 1.5. Update the classifier of the model to be compatible with our datasets

# %%
# In transfer learning, we freeze the feature parameters from the original model
# The most straightforward way is to freeze their gradient update
# see https://pytorch.org/docs/stable/generated/torch.Tensor.requires_grad.html for how to set it
for param in model.parameters():
    param.requires_grad = ???

print(model)

# This is the original classifier with alexnet
print()
print('Original classifier of Alexnet')
print(model.classifier)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
#
# Original classifier of Alexnet
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Linear(in_features=9216, out_features=4096, bias=True)
#   (2): ReLU(inplace=True)
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=4096, out_features=4096, bias=True)
#   (5): ReLU(inplace=True)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
# now we need to replace the classifier by our datasets
# Note, fc2's out_feature should match our number of classes, which is 102

# Tip: check the original AlexNet classifier for some thoughts; they are similar.

# Defining number of hidden units in our fully connected layer
hidden_units = 4096
number_of_flowers = len(class_to_idx)

# Defining the fully connected layer that will be trained on the flower images
classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(???, hidden_units)), # this should be a Linear layer; how should it be connected to the pretrained model?
    ('relu', nn.ReLU()),
    ('dropout', nn.Dropout(0.5)),
    ('fc2', nn.Linear(???, ???)), # what should be the output of this layer?
    ('output', nn.LogSoftmax(dim=1))
]))

# %%
# double check if the classifier of the model is updated.
model.classifier = classifier
print(model)

# %% [markdown]
# ### 1.6. Set up the configurations and train it!
# - epochs = 30
# - since it is a multiclassification problem, we use [negative log likelihood loss](https://pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html)
# - we use the [Adam optimizer](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html)
# - learning rate (lr) = 0.001
#
# In each epoch, we go through all the training samples to update the model, and evaluate with the validation samples to see how good the current model is.
# - accuracy: mean of the matches in predicted class and the labels
# - loss: negative log likelihood loss
#
#
# **Sample outputs are provided below; but yours may vary**
# **Your validation accuracy may be better than train; this is fine**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

epochs = ???
optimizer = optim.Adam(model.classifier.parameters(), lr=???)
criterion = ??? # this is the loss
print_every = 5

validation_accuracies, training_accuracies = [], []
validation_losses, training_losses = [], []

best_validation_accuracy = 0
best_model_weights = None

for e in range(epochs):

    training_loss = training_accuracy = 0
    validation_loss = validation_accuracy = 0

    model.train()
    for batch_idx, (images, labels) in enumerate(dataloaders['training']):

        # Moving images & labels to the GPU if there is one
        images, labels = images.to(device), labels.to(device)

        # Pushing batch through network, calculating loss & gradient, and updating weights
        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()

        # Calculating metrics
        ps = torch.exp(log_ps)
        top_ps, top_class = ps.topk(1, dim=1)
        matches = (top_class == labels.view(*top_class.shape)).type(
            torch.FloatTensor)
        train_batch_accuracy = matches.mean()

        # Resetting optimizer gradient & tracking metrics
        optimizer.zero_grad()
        training_loss += loss.item()
        train_batch_loss = loss.item()
        training_accuracy += train_batch_accuracy.item()

        if batch_idx % print_every == 0:
            # First analyze the training statistics
            print('epoch', e, 'batch', batch_idx)
            print('training loss per batch', train_batch_loss)
            print('training accuracy per batch', train_batch_accuracy.item())

    # Then do the analysis for the validation only at the end of each training epochs
    model.eval()
    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(
                dataloaders['validation']):
            images, labels = images.to(device), labels.to(device)
            log_ps = model(images)
            loss = ???
            ps = ???
            top_ps, top_class = ???
            matches = (top_class == labels.view(*top_class.shape)).type(
                torch.FloatTensor)
            validation_batch_accuracy = ???

            # Tracking validation metrics
            validation_loss += ???
            validation_batch_loss = ???
            validation_accuracy += ???

    # Save the best model weights so far
    # Tip: see this https://pytorch.org/tutorials/beginner/saving_loading_models.html
    if validation_accuracy >= best_validation_accuracy:
        best_validation_accuracy = ???
        best_model_weights = ???

    # Summary statistic per epoch
    print('epoch', e, 'summary')
    print('avg training loss per epoch', training_loss / training_len)
    print('avg training accuracy per epoch', training_accuracy / training_len)
    training_losses.append(training_loss / training_len)
    training_accuracies.append(training_accuracy / training_len)

    print('avg validation loss per epoch', validation_loss / validation_len)
    print('avg validation accuracy per epoch',
          validation_accuracy / validation_len)
    validation_losses.append(validation_loss / validation_len)
    validation_accuracies.append(validation_accuracy / validation_len)

    print()
# Out:
# epoch 0 batch 0
# training loss per batch 4.794888496398926
# training accuracy per batch 0.0234375
# epoch 0 batch 5
# training loss per batch 15.710596084594727
# training accuracy per batch 0.046875
# epoch 0 batch 10
# training loss per batch 8.43486213684082
# training accuracy per batch 0.125
# epoch 0 batch 15
# training loss per batch 3.7568283081054688
# training accuracy per batch 0.19921875
# epoch 0 batch 20
# training loss per batch 3.0758776664733887
# training accuracy per batch 0.26953125
# epoch 0 batch 25
# training loss per batch 2.886159896850586
# training accuracy per batch 0.32236841320991516
# epoch 0 summary
# avg training loss per epoch 7.527604093918433
# avg training accuracy per epoch 0.16489277550807366
# avg validation loss per epoch 1.9278140366077423
# avg validation accuracy per epoch 0.5333984345197678
#
# epoch 1 batch 0
# training loss per batch 2.713104724884033
# training accuracy per batch 0.33203125
# epoch 1 batch 5
# training loss per batch 2.347987174987793
# training accuracy per batch 0.40625
# epoch 1 batch 10
# training loss per batch 2.0354111194610596
# training accuracy per batch 0.5
# epoch 1 batch 15
# training loss per batch 2.0118520259857178
# training accuracy per batch 0.46875
# epoch 1 batch 20
# training loss per batch 1.9443739652633667
# training accuracy per batch 0.50390625
# epoch 1 batch 25
# training loss per batch 1.8533889055252075
# training accuracy per batch 0.5131579041481018
# epoch 1 summary
# avg training loss per epoch 2.1758221066915073
# avg training accuracy per epoch 0.4462692943903116
# avg validation loss per epoch 1.064510554075241
# avg validation accuracy per epoch 0.7206640690565109
#
# epoch 2 batch 0
# training loss per batch 1.5841667652130127
# training accuracy per batch 0.59375
# epoch 2 batch 5
# training loss per batch 1.906340479850769
# training accuracy per batch 0.49609375
# epoch 2 batch 10
# training loss per batch 1.4460577964782715
# training accuracy per batch 0.62890625
# epoch 2 batch 15
# training loss per batch 1.5120278596878052
# training accuracy per batch 0.6171875
# epoch 2 batch 20
# training loss per batch 1.6278327703475952
# training accuracy per batch 0.55859375
# epoch 2 batch 25
# training loss per batch 1.769856333732605
# training accuracy per batch 0.5131579041481018
# epoch 2 summary
# avg training loss per epoch 1.6366643905639648
# avg training accuracy per epoch 0.5642079963133886
# avg validation loss per epoch 0.7877418398857117
# avg validation accuracy per epoch 0.8016796857118607
#
# epoch 3 batch 0
# training loss per batch 1.3631858825683594
# training accuracy per batch 0.65234375
# epoch 3 batch 5
# training loss per batch 1.3545863628387451
# training accuracy per batch 0.65234375
# epoch 3 batch 10
# training loss per batch 1.2849457263946533
# training accuracy per batch 0.65234375
# epoch 3 batch 15
# training loss per batch 1.5657527446746826
# training accuracy per batch 0.61328125
# epoch 3 batch 20
# training loss per batch 1.4078384637832642
# training accuracy per batch 0.6328125
# epoch 3 batch 25
# training loss per batch 1.3459984064102173
# training accuracy per batch 0.6644737124443054
# epoch 3 summary
# avg training loss per epoch 1.412199460543119
# avg training accuracy per epoch 0.6211095658632425
# avg validation loss per epoch 0.6641963943839073
# avg validation accuracy per epoch 0.8132812529802322
#
# epoch 4 batch 0
# training loss per batch 1.2460919618606567
# training accuracy per batch 0.66015625
# epoch 4 batch 5
# training loss per batch 1.1927058696746826
# training accuracy per batch 0.66015625
# epoch 4 batch 10
# training loss per batch 1.4084632396697998
# training accuracy per batch 0.60546875
# epoch 4 batch 15
# training loss per batch 1.5028325319290161
# training accuracy per batch 0.60546875
# epoch 4 batch 20
# training loss per batch 1.3988628387451172
# training accuracy per batch 0.640625
# epoch 4 batch 25
# training loss per batch 1.1611140966415405
# training accuracy per batch 0.6842105388641357
# epoch 4 summary
# avg training loss per epoch 1.3108424819432771
# avg training accuracy per epoch 0.6389960784178513
# avg validation loss per epoch 0.604000598192215
# avg validation accuracy per epoch 0.8379296809434891
#
# epoch 5 batch 0
# training loss per batch 1.2962720394134521
# training accuracy per batch 0.65234375
# epoch 5 batch 5
# training loss per batch 1.2740927934646606
# training accuracy per batch 0.6484375
# epoch 5 batch 10
# training loss per batch 1.0719631910324097
# training accuracy per batch 0.66796875
# epoch 5 batch 15
# training loss per batch 1.250087022781372
# training accuracy per batch 0.67578125
# epoch 5 batch 20
# training loss per batch 1.1760152578353882
# training accuracy per batch 0.68359375
# epoch 5 batch 25
# training loss per batch 1.2644455432891846
# training accuracy per batch 0.6973684430122375
# epoch 5 summary
# avg training loss per epoch 1.2276522792302644
# avg training accuracy per epoch 0.6660946997312399
# avg validation loss per epoch 0.508320227265358
# avg validation accuracy per epoch 0.8528124988079071
#
# epoch 6 batch 0
# training loss per batch 1.0713310241699219
# training accuracy per batch 0.703125
# epoch 6 batch 5
# training loss per batch 1.0439614057540894
# training accuracy per batch 0.71484375
# epoch 6 batch 10
# training loss per batch 1.0319956541061401
# training accuracy per batch 0.69921875
# epoch 6 batch 15
# training loss per batch 1.2791310548782349
# training accuracy per batch 0.67578125
# epoch 6 batch 20
# training loss per batch 1.192452073097229
# training accuracy per batch 0.66015625
# epoch 6 batch 25
# training loss per batch 1.262307047843933
# training accuracy per batch 0.6644737124443054
# epoch 6 summary
# avg training loss per epoch 1.1244987616172204
# avg training accuracy per epoch 0.6882670177863195
# avg validation loss per epoch 0.5177859365940094
# avg validation accuracy per epoch 0.8663671910762787
#
# epoch 7 batch 0
# training loss per batch 1.0812132358551025
# training accuracy per batch 0.71875
# epoch 7 batch 5
# training loss per batch 1.0179003477096558
# training accuracy per batch 0.7109375
# epoch 7 batch 10
# training loss per batch 1.0396093130111694
# training accuracy per batch 0.7265625
# epoch 7 batch 15
# training loss per batch 1.1635183095932007
# training accuracy per batch 0.68359375
# epoch 7 batch 20
# training loss per batch 1.0689449310302734
# training accuracy per batch 0.6796875
# epoch 7 batch 25
# training loss per batch 1.155239462852478
# training accuracy per batch 0.6907894611358643
# epoch 7 summary
# avg training loss per epoch 1.1009378203978906
# avg training accuracy per epoch 0.6964907004283025
# avg validation loss per epoch 0.5302021205425262
# avg validation accuracy per epoch 0.8661328107118607
#
# epoch 8 batch 0
# training loss per batch 1.1210885047912598
# training accuracy per batch 0.71484375
# epoch 8 batch 5
# training loss per batch 1.1805083751678467
# training accuracy per batch 0.69140625
# epoch 8 batch 10
# training loss per batch 0.8935962915420532
# training accuracy per batch 0.75390625
# epoch 8 batch 15
# training loss per batch 1.0243417024612427
# training accuracy per batch 0.71484375
# epoch 8 batch 20
# training loss per batch 1.033066987991333
# training accuracy per batch 0.6953125
# epoch 8 batch 25
# training loss per batch 1.0707659721374512
# training accuracy per batch 0.7171052694320679
# epoch 8 summary
# avg training loss per epoch 1.0782411258954268
# avg training accuracy per epoch 0.7020100584396949
# avg validation loss per epoch 0.4699030816555023
# avg validation accuracy per epoch 0.8614843785762787
#
# epoch 9 batch 0
# training loss per batch 0.9682372808456421
# training accuracy per batch 0.71875
# epoch 9 batch 5
# training loss per batch 1.030236840248108
# training accuracy per batch 0.71875
# epoch 9 batch 10
# training loss per batch 1.0215702056884766
# training accuracy per batch 0.71875
# epoch 9 batch 15
# training loss per batch 1.1121492385864258
# training accuracy per batch 0.69921875
# epoch 9 batch 20
# training loss per batch 0.9210461378097534
# training accuracy per batch 0.73046875
# epoch 9 batch 25
# training loss per batch 1.264344334602356
# training accuracy per batch 0.6644737124443054
# epoch 9 summary
# avg training loss per epoch 1.0619338498665736
# avg training accuracy per epoch 0.7059953831709348
# avg validation loss per epoch 0.46613067388534546
# avg validation accuracy per epoch 0.8701562434434891
#
# epoch 10 batch 0
# training loss per batch 1.008081316947937
# training accuracy per batch 0.7265625
# epoch 10 batch 5
# training loss per batch 1.0319098234176636
# training accuracy per batch 0.71484375
# epoch 10 batch 10
# training loss per batch 1.1453510522842407
# training accuracy per batch 0.68359375
# epoch 10 batch 15
# training loss per batch 1.0361549854278564
# training accuracy per batch 0.72265625
# epoch 10 batch 20
# training loss per batch 1.0532588958740234
# training accuracy per batch 0.69140625
# epoch 10 batch 25
# training loss per batch 1.0590288639068604
# training accuracy per batch 0.6973684430122375
# epoch 10 summary
# avg training loss per epoch 1.0287401584478526
# avg training accuracy per epoch 0.7147725843466245
# avg validation loss per epoch 0.48117782175540924
# avg validation accuracy per epoch 0.8901562541723251
#
# epoch 11 batch 0
# training loss per batch 1.0188713073730469
# training accuracy per batch 0.71484375
# epoch 11 batch 5
# training loss per batch 0.9925636053085327
# training accuracy per batch 0.70703125
# epoch 11 batch 10
# training loss per batch 0.9093660116195679
# training accuracy per batch 0.7421875
# epoch 11 batch 15
# training loss per batch 1.1386799812316895
# training accuracy per batch 0.69140625
# epoch 11 batch 20
# training loss per batch 1.1276657581329346
# training accuracy per batch 0.70703125
# epoch 11 batch 25
# training loss per batch 0.8471882343292236
# training accuracy per batch 0.7368420958518982
# epoch 11 summary
# avg training loss per epoch 1.016827622285256
# avg training accuracy per epoch 0.7159903209943038
# avg validation loss per epoch 0.4952477514743805
# avg validation accuracy per epoch 0.8712500035762787
#
# epoch 12 batch 0
# training loss per batch 1.0027137994766235
# training accuracy per batch 0.734375
# epoch 12 batch 5
# training loss per batch 1.0959980487823486
# training accuracy per batch 0.69140625
# epoch 12 batch 10
# training loss per batch 1.1438339948654175
# training accuracy per batch 0.68359375
# epoch 12 batch 15
# training loss per batch 0.9999687671661377
# training accuracy per batch 0.6953125
# epoch 12 batch 20
# training loss per batch 0.944780707359314
# training accuracy per batch 0.7421875
# epoch 12 batch 25
# training loss per batch 0.9983924031257629
# training accuracy per batch 0.6776315569877625
# epoch 12 summary
# avg training loss per epoch 1.01090862430059
# avg training accuracy per epoch 0.7174690021918371
# avg validation loss per epoch 0.4549683630466461
# avg validation accuracy per epoch 0.8594140559434891
#
# epoch 13 batch 0
# training loss per batch 1.0436453819274902
# training accuracy per batch 0.6875
# epoch 13 batch 5
# training loss per batch 1.0161030292510986
# training accuracy per batch 0.703125
# epoch 13 batch 10
# training loss per batch 0.9500510096549988
# training accuracy per batch 0.7265625
# epoch 13 batch 15
# training loss per batch 1.0898865461349487
# training accuracy per batch 0.6953125
# epoch 13 batch 20
# training loss per batch 1.0232758522033691
# training accuracy per batch 0.73046875
# epoch 13 batch 25
# training loss per batch 0.9704335927963257
# training accuracy per batch 0.7105262875556946
# epoch 13 summary
# avg training loss per epoch 0.9909145923761221
# avg training accuracy per epoch 0.7250442802906036
# avg validation loss per epoch 0.4246569126844406
# avg validation accuracy per epoch 0.8872265666723251
#
# epoch 14 batch 0
# training loss per batch 1.031122088432312
# training accuracy per batch 0.75
# epoch 14 batch 5
# training loss per batch 0.963890016078949
# training accuracy per batch 0.73046875
# epoch 14 batch 10
# training loss per batch 0.8778820037841797
# training accuracy per batch 0.7421875
# epoch 14 batch 15
# training loss per batch 1.0630580186843872
# training accuracy per batch 0.71875
# epoch 14 batch 20
# training loss per batch 1.1136778593063354
# training accuracy per batch 0.69140625
# epoch 14 batch 25
# training loss per batch 0.9880185127258301
# training accuracy per batch 0.7565789222717285
# epoch 14 summary
# avg training loss per epoch 0.9776426186928382
# avg training accuracy per epoch 0.7319237085489126
# avg validation loss per epoch 0.48405539244413376
# avg validation accuracy per epoch 0.8682031184434891
#
# epoch 15 batch 0
# training loss per batch 0.8877443671226501
# training accuracy per batch 0.7421875
# epoch 15 batch 5
# training loss per batch 0.9806849956512451
# training accuracy per batch 0.70703125
# epoch 15 batch 10
# training loss per batch 1.058538794517517
# training accuracy per batch 0.6953125
# epoch 15 batch 15
# training loss per batch 0.9408621788024902
# training accuracy per batch 0.76953125
# epoch 15 batch 20
# training loss per batch 1.140486478805542
# training accuracy per batch 0.69921875
# epoch 15 batch 25
# training loss per batch 1.0309176445007324
# training accuracy per batch 0.7236841917037964
# epoch 15 summary
# avg training loss per epoch 1.0064430374365587
# avg training accuracy per epoch 0.7190900169886075
# avg validation loss per epoch 0.433672733604908
# avg validation accuracy per epoch 0.8742968738079071
#
# epoch 16 batch 0
# training loss per batch 1.0866074562072754
# training accuracy per batch 0.6640625
# epoch 16 batch 5
# training loss per batch 0.9193139672279358
# training accuracy per batch 0.72265625
# epoch 16 batch 10
# training loss per batch 0.8287081122398376
# training accuracy per batch 0.765625
# epoch 16 batch 15
# training loss per batch 0.8188367486000061
# training accuracy per batch 0.76171875
# epoch 16 batch 20
# training loss per batch 0.9475855827331543
# training accuracy per batch 0.75
# epoch 16 batch 25
# training loss per batch 1.12440824508667
# training accuracy per batch 0.7171052694320679
# epoch 16 summary
# avg training loss per epoch 0.9227602252593408
# avg training accuracy per epoch 0.7382179911320026
# avg validation loss per epoch 0.4327422305941582
# avg validation accuracy per epoch 0.8840624988079071
#
# epoch 17 batch 0
# training loss per batch 0.8588164448738098
# training accuracy per batch 0.76953125
# epoch 17 batch 5
# training loss per batch 0.9476837515830994
# training accuracy per batch 0.73046875
# epoch 17 batch 10
# training loss per batch 0.8279157280921936
# training accuracy per batch 0.7578125
# epoch 17 batch 15
# training loss per batch 1.0658105611801147
# training accuracy per batch 0.70703125
# epoch 17 batch 20
# training loss per batch 0.9434544444084167
# training accuracy per batch 0.72265625
# epoch 17 batch 25
# training loss per batch 0.6473937630653381
# training accuracy per batch 0.8223684430122375
# epoch 17 summary
# avg training loss per epoch 0.9113833285295047
# avg training accuracy per epoch 0.7485766708850861
# avg validation loss per epoch 0.442914254963398
# avg validation accuracy per epoch 0.8857812434434891
#
# epoch 18 batch 0
# training loss per batch 0.758249044418335
# training accuracy per batch 0.796875
# epoch 18 batch 5
# training loss per batch 0.9600809812545776
# training accuracy per batch 0.76953125
# epoch 18 batch 10
# training loss per batch 0.8046392202377319
# training accuracy per batch 0.76953125
# epoch 18 batch 15
# training loss per batch 0.9981903433799744
# training accuracy per batch 0.6953125
# epoch 18 batch 20
# training loss per batch 0.976594865322113
# training accuracy per batch 0.73828125
# epoch 18 batch 25
# training loss per batch 0.7860054969787598
# training accuracy per batch 0.75
# epoch 18 summary
# avg training loss per epoch 0.9427849902556493
# avg training accuracy per epoch 0.7414362980769231
# avg validation loss per epoch 0.42298633605241776
# avg validation accuracy per epoch 0.8811328113079071
#
# epoch 19 batch 0
# training loss per batch 0.7616268992424011
# training accuracy per batch 0.7890625
# epoch 19 batch 5
# training loss per batch 0.9397958517074585
# training accuracy per batch 0.75
# epoch 19 batch 10
# training loss per batch 0.6956744194030762
# training accuracy per batch 0.8046875
# epoch 19 batch 15
# training loss per batch 0.9342899322509766
# training accuracy per batch 0.765625
# epoch 19 batch 20
# training loss per batch 0.963145911693573
# training accuracy per batch 0.73046875
# epoch 19 batch 25
# training loss per batch 0.8963074088096619
# training accuracy per batch 0.7171052694320679
# epoch 19 summary
# avg training loss per epoch 0.9427299407812265
# avg training accuracy per epoch 0.738368231516618
# avg validation loss per epoch 0.38353586941957474
# avg validation accuracy per epoch 0.8932031244039536
#
# epoch 20 batch 0
# training loss per batch 0.9681178331375122
# training accuracy per batch 0.73828125
# epoch 20 batch 5
# training loss per batch 1.0460515022277832
# training accuracy per batch 0.71484375
# epoch 20 batch 10
# training loss per batch 1.0276144742965698
# training accuracy per batch 0.72265625
# epoch 20 batch 15
# training loss per batch 0.9476022720336914
# training accuracy per batch 0.73046875
# epoch 20 batch 20
# training loss per batch 1.1099859476089478
# training accuracy per batch 0.69140625
# epoch 20 batch 25
# training loss per batch 0.8168521523475647
# training accuracy per batch 0.7763158082962036
# epoch 20 summary
# avg training loss per epoch 0.9186529769347265
# avg training accuracy per epoch 0.7415470022421616
# avg validation loss per epoch 0.38712651282548904
# avg validation accuracy per epoch 0.8890624940395355
#
# epoch 21 batch 0
# training loss per batch 1.0239320993423462
# training accuracy per batch 0.72265625
# epoch 21 batch 5
# training loss per batch 0.9500818252563477
# training accuracy per batch 0.7421875
# epoch 21 batch 10
# training loss per batch 0.9803442358970642
# training accuracy per batch 0.7578125
# epoch 21 batch 15
# training loss per batch 0.9649176597595215
# training accuracy per batch 0.73828125
# epoch 21 batch 20
# training loss per batch 0.8976649641990662
# training accuracy per batch 0.7421875
# epoch 21 batch 25
# training loss per batch 0.743985652923584
# training accuracy per batch 0.7697368264198303
# epoch 21 summary
# avg training loss per epoch 0.9234822117365323
# avg training accuracy per epoch 0.7421954067853781
# avg validation loss per epoch 0.42757271230220795
# avg validation accuracy per epoch 0.8741796910762787
#
# epoch 22 batch 0
# training loss per batch 0.899124264717102
# training accuracy per batch 0.734375
# epoch 22 batch 5
# training loss per batch 0.73480623960495
# training accuracy per batch 0.81640625
# epoch 22 batch 10
# training loss per batch 0.9798426628112793
# training accuracy per batch 0.74609375
# epoch 22 batch 15
# training loss per batch 0.7611135244369507
# training accuracy per batch 0.80859375
# epoch 22 batch 20
# training loss per batch 1.020077109336853
# training accuracy per batch 0.70703125
# epoch 22 batch 25
# training loss per batch 0.9923111796379089
# training accuracy per batch 0.7565789222717285
# epoch 22 summary
# avg training loss per epoch 0.902034560075173
# avg training accuracy per epoch 0.7520559200873742
# avg validation loss per epoch 0.4664095714688301
# avg validation accuracy per epoch 0.8761328160762787
#
# epoch 23 batch 0
# training loss per batch 0.7414618134498596
# training accuracy per batch 0.79296875
# epoch 23 batch 5
# training loss per batch 1.0064973831176758
# training accuracy per batch 0.70703125
# epoch 23 batch 10
# training loss per batch 0.9715784192085266
# training accuracy per batch 0.703125
# epoch 23 batch 15
# training loss per batch 1.0027966499328613
# training accuracy per batch 0.734375
# epoch 23 batch 20
# training loss per batch 0.8705148696899414
# training accuracy per batch 0.78515625
# epoch 23 batch 25
# training loss per batch 0.63702791929245
# training accuracy per batch 0.8552631735801697
# epoch 23 summary
# avg training loss per epoch 0.9028085928696853
# avg training accuracy per epoch 0.746536564368468
# avg validation loss per epoch 0.4464425593614578
# avg validation accuracy per epoch 0.8758984357118607
#
# epoch 24 batch 0
# training loss per batch 0.8902440071105957
# training accuracy per batch 0.76953125
# epoch 24 batch 5
# training loss per batch 0.7646031975746155
# training accuracy per batch 0.78515625
# epoch 24 batch 10
# training loss per batch 0.9636426568031311
# training accuracy per batch 0.71484375
# epoch 24 batch 15
# training loss per batch 0.831831693649292
# training accuracy per batch 0.76953125
# epoch 24 batch 20
# training loss per batch 0.8370799422264099
# training accuracy per batch 0.7890625
# epoch 24 batch 25
# training loss per batch 0.8686225414276123
# training accuracy per batch 0.75
# epoch 24 summary
# avg training loss per epoch 0.9345084016139691
# avg training accuracy per epoch 0.7459435096153846
# avg validation loss per epoch 0.5018604919314384
# avg validation accuracy per epoch 0.8621093779802322
#
# epoch 25 batch 0
# training loss per batch 0.86016845703125
# training accuracy per batch 0.7734375
# epoch 25 batch 5
# training loss per batch 0.8299738764762878
# training accuracy per batch 0.78515625
# epoch 25 batch 10
# training loss per batch 1.0908912420272827
# training accuracy per batch 0.6875
# epoch 25 batch 15
# training loss per batch 0.9748476147651672
# training accuracy per batch 0.71484375
# epoch 25 batch 20
# training loss per batch 0.8850564360618591
# training accuracy per batch 0.75
# epoch 25 batch 25
# training loss per batch 0.8792475461959839
# training accuracy per batch 0.7368420958518982
# epoch 25 summary
# avg training loss per epoch 0.8935904869666467
# avg training accuracy per epoch 0.750846090225073
# avg validation loss per epoch 0.38948141783475876
# avg validation accuracy per epoch 0.9007812440395355
#
# epoch 26 batch 0
# training loss per batch 0.8491882085800171
# training accuracy per batch 0.75
# epoch 26 batch 5
# training loss per batch 0.849226176738739
# training accuracy per batch 0.78515625
# epoch 26 batch 10
# training loss per batch 0.715071439743042
# training accuracy per batch 0.7890625
# epoch 26 batch 15
# training loss per batch 0.8929964900016785
# training accuracy per batch 0.75390625
# epoch 26 batch 20
# training loss per batch 0.8313122391700745
# training accuracy per batch 0.765625
# epoch 26 batch 25
# training loss per batch 0.8934200406074524
# training accuracy per batch 0.75
# epoch 26 summary
# avg training loss per epoch 0.8833872698820554
# avg training accuracy per epoch 0.7555588942307693
# avg validation loss per epoch 0.4205029681324959
# avg validation accuracy per epoch 0.8879687488079071
#
# epoch 27 batch 0
# training loss per batch 0.8912488222122192
# training accuracy per batch 0.7421875
# epoch 27 batch 5
# training loss per batch 0.7686194181442261
# training accuracy per batch 0.78515625
# epoch 27 batch 10
# training loss per batch 0.8746477365493774
# training accuracy per batch 0.7734375
# epoch 27 batch 15
# training loss per batch 0.9386981725692749
# training accuracy per batch 0.74609375
# epoch 27 batch 20
# training loss per batch 0.9770939350128174
# training accuracy per batch 0.734375
# epoch 27 batch 25
# training loss per batch 1.0814743041992188
# training accuracy per batch 0.7302631735801697
# epoch 27 summary
# avg training loss per epoch 0.8848538582141583
# avg training accuracy per epoch 0.7587060355223142
# avg validation loss per epoch 0.5007760748267174
# avg validation accuracy per epoch 0.8998046815395355
#
# epoch 28 batch 0
# training loss per batch 1.0106059312820435
# training accuracy per batch 0.6953125
# epoch 28 batch 5
# training loss per batch 0.7058916687965393
# training accuracy per batch 0.80078125
# epoch 28 batch 10
# training loss per batch 0.7496168613433838
# training accuracy per batch 0.80859375
# epoch 28 batch 15
# training loss per batch 0.9306085705757141
# training accuracy per batch 0.73828125
# epoch 28 batch 20
# training loss per batch 0.8619073033332825
# training accuracy per batch 0.78125
# epoch 28 batch 25
# training loss per batch 0.7493762373924255
# training accuracy per batch 0.7828947305679321
# epoch 28 summary
# avg training loss per epoch 0.8663772527988141
# avg training accuracy per epoch 0.762382970406459
# avg validation loss per epoch 0.42013484239578247
# avg validation accuracy per epoch 0.8907812535762787
#
# epoch 29 batch 0
# training loss per batch 0.9931778907775879
# training accuracy per batch 0.7734375
# epoch 29 batch 5
# training loss per batch 0.7364280223846436
# training accuracy per batch 0.796875
# epoch 29 batch 10
# training loss per batch 0.9351009130477905
# training accuracy per batch 0.76953125
# epoch 29 batch 15
# training loss per batch 0.9342491626739502
# training accuracy per batch 0.73828125
# epoch 29 batch 20
# training loss per batch 0.9811995029449463
# training accuracy per batch 0.69140625
# epoch 29 batch 25
# training loss per batch 0.9085271954536438
# training accuracy per batch 0.7565789222717285
# epoch 29 summary
# avg training loss per epoch 0.8913000134321359
# avg training accuracy per epoch 0.7561124104719895
# avg validation loss per epoch 0.4550979733467102
# avg validation accuracy per epoch 0.8939453065395355

# %% [markdown]
# ### *Question 3: Report the best model's validation accuracy*
# best_validation_accuracy = ???

# %% [markdown]
# ### 1.7. Draw learning curves

# %%
plt.figure()
plt.title("Training Summary of Loss")
plt.plot(training_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure()
plt.title("Training Summary of Accuracy")
plt.plot(training_accuracies, label='Training Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### *Question 4: Briefly describe the plots*

# %% [markdown]
# ### 1.8. Predict on the test data with the best model so far

# %%
# Predict on the test data

# Load the best model so far
model.load_state_dict(best_model_weights)
test_accuracy = 0

predictions = []
label_data = []

for images, labels in dataloaders['testing']:
    ???
    ???
    ???
    ???
    # Try to do similar things as validation to get the test accuracy
    # You also need to store the predictions and labels for all the test data, which will be used later
    # you could save them in predictions and label_data
print('Test Accuracy:', test_accuracy.item() / test_len)

# %% [markdown]
# ### *Question 5: Report the test accuracy with the best model*

# %% [markdown]
# ### *Question 6: Provide a confusion matrix between the ground truth and predicted labels in the test dataset. The rows should correspond to the ground ruth categories and the columns to predicted categories. The confusion matrix here should have raw datapoint counts and should not be normalized as percentages*
#
# ### *Question 7: Now normalize the raw confusion matrix reported in the previous question by dividing each row by the sum of all its elements. Include this normalized confusion matrix in your report. It may look small but that is fine. What does the diagnal denote in the normalized confusion matrix? What is the meaning of the number in the row 1 column 2?*

# %%
# Please plot the confusion matrix other than print() if possible
from sklearn.metrics import confusion_matrix as conf_mat
import numpy as np
cf =conf_mat(label_data,predictions)

print('confusion matrix')
print(cf)
print()
plt.???

# normalized confusion matrix
print('normalized confusion matrix')
ncf = ???
print(ncf)
plt.???

# %% [markdown]
# ### *Question 8: Transfer Learning*
# - What is the purpose of a pretrained model and why should it work?
# - Why should we freeze the features' gradient in the pretrained model but only update the classifier?
# - What may happen if we do not freeze the features' gradient?
